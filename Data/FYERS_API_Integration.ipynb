# %%
pip install fyers-apiv3
# Out:
# Requirement already satisfied: fyers-apiv3 in /opt/anaconda3/lib/python3.13/site-packages (3.1.7)
# Requirement already satisfied: requests==2.31.0 in /opt/anaconda3/lib/python3.13/site-packages (from fyers-apiv3) (2.31.0)
# Requirement already satisfied: asyncio==3.4.3 in /opt/anaconda3/lib/python3.13/site-packages (from fyers-apiv3) (3.4.3)
# Requirement already satisfied: aiohttp==3.9.3 in /opt/anaconda3/lib/python3.13/site-packages (from fyers-apiv3) (3.9.3)
# Requirement already satisfied: aws_lambda_powertools==1.25.5 in /opt/anaconda3/lib/python3.13/site-packages (from fyers-apiv3) (1.25.5)
# Requirement already satisfied: websocket-client==1.6.1 in /opt/anaconda3/lib/python3.13/site-packages (from fyers-apiv3) (1.6.1)
# Requirement already satisfied: protobuf==5.29.3 in /opt/anaconda3/lib/python3.13/site-packages (from fyers-apiv3) (5.29.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp==3.9.3->fyers-apiv3) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp==3.9.3->fyers-apiv3) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp==3.9.3->fyers-apiv3) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp==3.9.3->fyers-apiv3) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp==3.9.3->fyers-apiv3) (1.18.0)
# Requirement already satisfied: aws-xray-sdk<3.0.0,>=2.8.0 in /opt/anaconda3/lib/python3.13/site-packages (from aws_lambda_powertools==1.25.5->fyers-apiv3) (2.15.0)
# Requirement already satisfied: boto3<2.0,>=1.18 in /opt/anaconda3/lib/python3.13/site-packages (from aws_lambda_powertools==1.25.5->fyers-apiv3) (1.42.24)
# Requirement already satisfied: fastjsonschema<3.0.0,>=2.14.5 in /opt/anaconda3/lib/python3.13/site-packages (from aws_lambda_powertools==1.25.5->fyers-apiv3) (2.20.0)
# Requirement already satisfied: jmespath<0.11.0,>=0.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from aws_lambda_powertools==1.25.5->fyers-apiv3) (0.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests==2.31.0->fyers-apiv3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests==2.31.0->fyers-apiv3) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests==2.31.0->fyers-apiv3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests==2.31.0->fyers-apiv3) (2025.8.3)
# Requirement already satisfied: wrapt in /opt/anaconda3/lib/python3.13/site-packages (from aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers-apiv3) (1.17.0)
# Requirement already satisfied: botocore>=1.11.3 in /opt/anaconda3/lib/python3.13/site-packages (from aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers-apiv3) (1.42.24)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /opt/anaconda3/lib/python3.13/site-packages (from boto3<2.0,>=1.18->aws_lambda_powertools==1.25.5->fyers-apiv3) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/lib/python3.13/site-packages (from botocore>=1.11.3->aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers-apiv3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->botocore>=1.11.3->aws-xray-sdk<3.0.0,>=2.8.0->aws_lambda_powertools==1.25.5->fyers-apiv3) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.0->aiohttp==3.9.3->fyers-apiv3) (0.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **SCRIPT TO GENERATE auth URL**

# %%
from fyers_apiv3 import fyersModel
from config import CLIENT_ID, SECRET_KEY, REDIRECT_URI

# Initialize Session Model using credentials from config
session = fyersModel.SessionModel(
    client_id=CLIENT_ID,
    redirect_uri=REDIRECT_URI,
    response_type="code",
    state="hackathon",
    secret_key=SECRET_KEY,
    grant_type="authorization_code"
)

# Generate Auth URL
auth_url = session.generate_authcode()
print("Open this URL in browser:\n", auth_url)
# Out:
# Open this URL in browser:
#  https://api-t1.fyers.in/api/v3/generate-authcode?client_id=6LV74LVY1F-100&redirect_uri=http%3A%2F%2F127.0.0.1%3A5000%2Fredirect&response_type=code&state=hackathon

# %% [markdown]
# ### **GENERATE ACCESS TOKEN**

# %%
from fyers_apiv3 import fyersModel
from config import CLIENT_ID, SECRET_KEY, REDIRECT_URI

# 1. PASTE AUTH CODE HERE (From Browser)
AUTH_CODE = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....nDNWNMcApeOFFEZI8cfjDp-ybpWIVcKWBF4kQiyY9vQ"

# 2. Initialize Session
session = fyersModel.SessionModel(
    client_id=CLIENT_ID,
    secret_key=SECRET_KEY,
    redirect_uri=REDIRECT_URI,
    response_type="code",
    grant_type="authorization_code"
)

# 3. Generate & SAVE Token
session.set_token(AUTH_CODE)
response = session.generate_token()

if response['s'] == 'ok':
    access_token = response['access_token']
    
    # --- SAVE TO FILE ---
    with open("access_token.txt", "w") as f:
        f.write(access_token)
    print("✅ Success! Access Token saved to 'access_token.txt'")
else:
    print("❌ Error generating token:", response)
# Out:
# ✅ Success! Access Token saved to 'access_token.txt'

# %% [markdown]
# ### **Freeze authentication**

# %%
from fyers_apiv3 import fyersModel
from config import CLIENT_ID
import os

# 1. LOAD TOKEN FROM FILE
try:
    with open("access_token.txt", "r") as f:
        access_token = f.read().strip()
    print("✅ Loaded Access Token from file.")
except FileNotFoundError:
    print("❌ Error: 'access_token.txt' not found. Please run the generation step first.")

# 2. Initialize Fyers Function
def get_fyers():
    return fyersModel.FyersModel(
        client_id=CLIENT_ID,
        token=access_token,
        log_path="./logs"
    )

# Test it
fyers = get_fyers()
print("Fyers Model Initialized!")
# Out:
# ✅ Loaded Access Token from file.
# Fyers Model Initialized!

# %% [markdown]
# ### **HISTORICAL DATA FETCH**

# %%
from datetime import datetime
import os

# Ensure logs directory exists (FYERS SDK requirement)
os.makedirs("./logs", exist_ok=True)

# Initialize FYERS client
fyers = get_fyers()

def fetch_ohlcv(fyers, symbol, start, end):
    "Fetch daily OHLCV data from FYERS (2-month window)."

    data = {
        "symbol": f"NSE:{symbol}",
        "resolution": "D",                  # Daily data only
        "date_format": "0",                 # Unix timestamps
        "range_from": int(start.timestamp()),
        "range_to": int(end.timestamp()),
        "cont_flag": "1"
    }

    response = fyers.history(data)
    print(response)   # Keep this for debugging & transparency

    return response

# %% [markdown]
# ### **HISTORICAL DATA FETCH SANITY CHECK**

# %%
start_date = datetime(2025, 11, 1)
end_date   = datetime(2025, 12, 31)

resp = fetch_ohlcv(
    fyers=fyers,
    symbol="SONATSOFTW-EQ",
    start=start_date,
    end=end_date
)
# Out:
# {'candles': [[1762128000, 370.25, 374.5, 369.05, 371.7, 266050], [1762214400, 371.7, 376, 368.4, 374.25, 296116], [1762387200, 372.5, 375, 363.1, 365.85, 323191], [1762473600, 363, 369.5, 358, 367.8, 301377], [1762732800, 367.75, 379, 365.1, 376.15, 728662], [1762819200, 376.2, 378, 370.15, 371.8, 299607], [1762905600, 373.8, 396.5, 372, 392.8, 2801504], [1762992000, 393.05, 400.5, 386, 389.4, 995358], [1763078400, 390, 390, 364, 374.15, 2305036], [1763337600, 374, 375, 368.05, 370.95, 874111], [1763424000, 370.1, 370.95, 363.6, 365.5, 623100], [1763510400, 366.5, 376.9, 362.6, 370.05, 1382029], [1763596800, 371.05, 372.45, 362.1, 364.95, 635123], [1763683200, 364.95, 365.9, 356.25, 358.05, 375039], [1763942400, 358.25, 364.5, 358, 360.3, 650417], [1764028800, 362, 364, 355.95, 357.95, 345435], [1764115200, 360.45, 361.45, 356.1, 360.4, 375441], [1764201600, 362.85, 363.05, 355.55, 357.05, 302290], [1764288000, 357.95, 365, 354.4, 357.4, 774003], [1764547200, 358.55, 364.2, 357.2, 358.8, 313926], [1764633600, 360, 360.3, 349.45, 350.1, 660702], [1764720000, 352.05, 372, 351.9, 364.45, 7681554], [1764806400, 365, 374.8, 363.75, 365.55, 1934702], [1764892800, 365.6, 365.8, 357.1, 361.2, 668416], [1765152000, 361.4, 363.1, 351.2, 354.75, 453702], [1765238400, 355.4, 355.9, 345, 348.85, 493734], [1765324800, 351.7, 355.7, 346.3, 347.85, 431089], [1765411200, 350, 352.9, 341.2, 351.2, 538827], [1765497600, 354.5, 354.5, 348.95, 350.05, 433815], [1765756800, 350, 350.1, 346.75, 349.4, 226593], [1765843200, 350.5, 350.5, 341.9, 344.55, 616427], [1765929600, 344.55, 345.15, 340.5, 341.55, 320016], [1766016000, 340.8, 344, 338.2, 339.7, 325433], [1766102400, 342.9, 345.9, 341.1, 344.6, 498925], [1766361600, 348.35, 357.8, 348.15, 351.85, 720109], [1766448000, 354, 366, 350.75, 362.75, 1305993], [1766534400, 361.8, 362.6, 354.9, 359.2, 683228], [1766707200, 360.05, 370.85, 356.55, 366.65, 936745], [1766966400, 366.65, 367.45, 353.3, 356.9, 700300], [1767052800, 356.3, 363.5, 352.5, 357.25, 731583], [1767139200, 359, 364.85, 357.85, 359.85, 233015]], 'code': 200, 'message': '', 's': 'ok'}

# %% [markdown]
# ### **CONVERTING CANDLES To Pandas Df and Saving to CSV**

# %%
import pandas as pd

def candles_to_df(candles):
    df = pd.DataFrame(
        candles,
        columns=["timestamp", "open", "high", "low", "close", "volume"]
    )
    df["timestamp"] = pd.to_datetime(df["timestamp"], unit="s")
    df.set_index("timestamp", inplace=True)
    return df

df = candles_to_df(resp["candles"])
df.head()
# Out:
#               open   high     low   close  volume
# timestamp
# 2025-11-03  370.25  374.5  369.05  371.70  266050
# 2025-11-04  371.70  376.0  368.40  374.25  296116
# 2025-11-06  372.50  375.0  363.10  365.85  323191
# 2025-11-07  363.00  369.5  358.00  367.80  301377
# 2025-11-10  367.75  379.0  365.10  376.15  728662

# %%
df.to_csv("SONATSOFTW_daily_2025_11_12.csv")
# Saving to CSV
